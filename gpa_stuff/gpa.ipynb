# %%
from pathlib import Path
import pandas as pd

raw_dir = Path('gpa-raw')
csv_paths = sorted(raw_dir.glob('*.csv'))

def read_csv_with_debug(csv_path):
    try:
        df = pd.read_csv(csv_path)
        return df
    except UnicodeDecodeError as exc:
        # Locate the problematic byte to help fix the source CSV
        with open(csv_path, 'rb') as fh:
            raw = fh.read()
        start = max(exc.start - 40, 0)
        end = min(exc.end + 40, len(raw))
        snippet = raw[start:end]
        print(f'UnicodeDecodeError in {csv_path.name} at bytes {exc.start}:{exc.end}')
        print('Raw bytes near error:', snippet)
        print('Raw bytes as latin-1:', snippet.decode('latin-1', errors='replace'))
        raise

dfs = []
for csv_path in csv_paths:
    df = read_csv_with_debug(csv_path)
    df['source_file'] = csv_path.name
    dfs.append(df)

gpa_raw = pd.concat(dfs, ignore_index=True)
gpa_raw
# Out:
#             CRN Course Subject  Course Number                  Course Title  \
# 0       41758.0            AAS          100.0  Intro Asian American Studies
# 1       47102.0            AAS          100.0  Intro Asian American Studies
# 2       51248.0            AAS          100.0  Intro Asian American Studies
# 3       51249.0            AAS          100.0  Intro Asian American Studies
# 4       51932.0            AAS          100.0  Intro Asian American Studies
# ...         ...            ...            ...                           ...
# 122578  10060.0           PSYC          204.0  Intro to Brain and Cognition
# 122579  10106.0            REL          110.0               World Religions
# 122580  10039.0           SPAN          130.0          Intermediate Spanish
# 122581  10102.0           SPAN          130.0          Intermediate Spanish
# 122582  10040.0           SPAN          142.0    Spanish in the Professions
#
#        Course Section Sched Type      Term   Primary Instructor    A+     A  \
# 0                 AD1        DIS  120108.0  Winkelmann, Marie T   1.0  12.0
# 1                 AD3        DIS  120108.0        Kwon, Yaejoon   2.0   6.0
# 2                 AD4        DIS  120108.0        Kwon, Yaejoon   4.0   4.0
# 3                 AD5        DIS  120108.0  Arnaldo, Constancio   0.0   9.0
# 4                 AD6        DIS  120108.0  Arnaldo, Constancio   0.0  13.0
# ...               ...        ...       ...                  ...   ...   ...
# 122578              A        ONL  120250.0      Dolcos, Sanda M   5.0  15.0
# 122579            AL1        ONL  120250.0     Ebel, Jonathan H   0.0  31.0
# 122580              A        ONL  120250.0      Abbott, Annie R  10.0   9.0
# 122581              B        ONL  120250.0      Hughes, Brady A   6.0   4.0
# 122582              A        ONL  120250.0   Dutton, Michelle M  13.0   7.0
#
#         ...  % 4.0's      source_file  Subject  Course  A Range  B Range  \
# 0       ...      38%       fa2010.csv      NaN     NaN      NaN      NaN
# 1       ...      25%       fa2010.csv      NaN     NaN      NaN      NaN
# 2       ...      28%       fa2010.csv      NaN     NaN      NaN      NaN
# 3       ...      26%       fa2010.csv      NaN     NaN      NaN      NaN
# 4       ...      37%       fa2010.csv      NaN     NaN      NaN      NaN
# ...     ...      ...              ...      ...     ...      ...      ...
# 122578  ...      NaN  wi2024_2025.csv      NaN     NaN      NaN      NaN
# 122579  ...      NaN  wi2024_2025.csv      NaN     NaN      NaN      NaN
# 122580  ...      NaN  wi2024_2025.csv      NaN     NaN      NaN      NaN
# 122581  ...      NaN  wi2024_2025.csv      NaN     NaN      NaN      NaN
# 122582  ...      NaN  wi2024_2025.csv      NaN     NaN      NaN      NaN
#
#         C Range  D Range  Course   Section
# 0           NaN      NaN      NaN      NaN
# 1           NaN      NaN      NaN      NaN
# 2           NaN      NaN      NaN      NaN
# 3           NaN      NaN      NaN      NaN
# 4           NaN      NaN      NaN      NaN
# ...         ...      ...      ...      ...
# 122578      NaN      NaN      NaN      NaN
# 122579      NaN      NaN      NaN      NaN
# 122580      NaN      NaN      NaN      NaN
# 122581      NaN      NaN      NaN      NaN
# 122582      NaN      NaN      NaN      NaN
#
# [122583 rows x 34 columns]

# %%
# Verify every Primary Instructor has exactly one comma
# (ignoring any trailing comma with nothing after it)
instructor_series = gpa_raw['Primary Instructor'].astype(str).str.strip()
instructor_series = instructor_series.str.replace(r',$', '', regex=True)
comma_counts = instructor_series.str.count(',')

invalid_instructors = gpa_raw.loc[comma_counts != 1, 'Primary Instructor'].unique()
invalid_instructors
# Out:
# array([nan], dtype=object)

# %%
# Build a master df with one row per course-instructor and average GPA over sections
required_cols = ['Course Subject', 'Course Number', 'Primary Instructor']
gpa_filtered = gpa_raw.dropna(subset=required_cols).copy()

course_subject = gpa_filtered['Course Subject'].astype(str).str.strip()
course_number = gpa_filtered['Course Number'].astype(str).str.strip()
course_number = course_number.str.replace(r'\.0$', '', regex=True)
course_name = gpa_filtered['Course Title'].astype(str).str.strip()

instructor_clean = gpa_filtered['Primary Instructor'].astype(str).str.strip()
instructor_clean = instructor_clean.str.replace(r',$', '', regex=True)

instructor_split = instructor_clean.str.split(',', n=1, expand=True)
instructor_last = instructor_split[0].str.strip()
instructor_first = instructor_split[1].str.strip()

gpa_filtered = gpa_filtered.assign(
    course_subject=course_subject,
    course_number=course_number,
    course_name=course_name,
    instructor_last=instructor_last,
    instructor_first=instructor_first,
)

gpa_filtered['Average Grade'] = pd.to_numeric(gpa_filtered['Average Grade'], errors='coerce')

master_df = (
    gpa_filtered
    .groupby(
        ['course_subject', 'course_number', 'course_name', 'instructor_last', 'instructor_first'],
        as_index=False,
    )['Average Grade']
    .mean()
    .rename(columns={'Average Grade': 'avg_gpa'})
)

master_df
# Out:
#       course_subject course_number                   course_name  \
# 0                AAS           100  Intro Asian American Studies
# 1                AAS           100  Intro Asian American Studies
# 2                AAS           100  Intro Asian American Studies
# 3                AAS           100  Intro Asian American Studies
# 4                AAS           100  Intro Asian American Studies
# ...              ...           ...                           ...
# 33248           ZULU           403           Intermediate Zulu I
# 33249           ZULU           404          Intermediate Zulu II
# 33250           ZULU           404          Intermediate Zulu II
# 33251           ZULU           406              Advanced Zulu II
# 33252           ZULU           406              Advanced Zulu II
#
#       instructor_last instructor_first   avg_gpa
# 0                Arai           Sayuri  3.640000
# 1             Arnaldo       Constancio  3.597500
# 2              Carter         Regina S  3.745000
# 3             Charity         Hannah L       NaN
# 4               Davis         Thomas E  3.697143
# ...               ...              ...       ...
# 33248         Hlongwa        Tholani S       NaN
# 33249         Hlongwa        Tholani S       NaN
# 33250       Mkhatshwa     Telamisile P       NaN
# 33251         Hlongwa        Tholani S       NaN
# 33252          Madela     Mbhekiseni L       NaN
#
# [33253 rows x 6 columns]

# %%
filtered_master_df = master_df[master_df['avg_gpa'] > 0]


filtered_master_df
# Out:
#       course_subject course_number                     course_name  \
# 0                AAS           100    Intro Asian American Studies
# 1                AAS           100    Intro Asian American Studies
# 2                AAS           100    Intro Asian American Studies
# 4                AAS           100    Intro Asian American Studies
# 5                AAS           100    Intro Asian American Studies
# ...              ...           ...                             ...
# 33218             VM           655     SA Medicine and Surgery III
# 33219             VM           656     LA Medicine and Surgery III
# 33239           YDSH           220             Jewish Storytelling
# 33242           YDSH           320  Lit Responses to the Holocaust
# 33243           YDSH           320  Lit Responses to the Holocaust
#
#       instructor_last instructor_first   avg_gpa
# 0                Arai           Sayuri  3.640000
# 1             Arnaldo       Constancio  3.597500
# 2              Carter         Regina S  3.745000
# 4               Davis         Thomas E  3.697143
# 5                Geng              Zhe  3.750000
# ...               ...              ...       ...
# 33218         Ridgway       Marcella D  2.760000
# 33219         Garrett          Edgar F  2.875000
# 33239          Harris         Rachel S  3.560000
# 33242         Elliott        Jeffrey P  3.920000
# 33243          Kaplan          Brett A  3.376667
#
# [16149 rows x 6 columns]

# %%
filtered_master_df.to_csv('filtered_master_df_01122026.csv', index=False)

# %%
# Export master_df to a JSON grouped by course_name
import json
from pathlib import Path

output_path = Path('/Users/aneeshkalla/Desktop/scheduler/gpa_stuff/gpa.json')

grouped = {}
for _, row in filtered_master_df.iterrows():
    course = row['course_subject'] + ' ' + row['course_number']
    entry = {
        'last': row['instructor_last'],
        'first': row['instructor_first'],
        'gpa': row['avg_gpa'],
    }
    grouped.setdefault(course, []).append(entry)

output_path.write_text(json.dumps(grouped, indent=2))
output_path
# Out:
# PosixPath('/Users/aneeshkalla/Desktop/scheduler/gpa_stuff/gpa.json')
